# %%
# Install libraries if not already installed
# !pip install transformers torch


# Import Hugging Face pipeline
from transformers import pipeline


# Load pretrained GPT-2 text generation model
generator = pipeline(
    "text-generation",
    model="gpt2"
)


# Function to generate text
def generate_text(prompt):

    result = generator(
        prompt,
        max_length=100,
        num_return_sequences=1,
        truncation=True
    )

    return result[0]["generated_text"]


# Get input from user
user_input = input("Enter a sentence or topic: ")


# Generate text
generated_text = generate_text(user_input)


# Display output
print("\nGenerated Text:\n")

print(generated_text)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Enter a sentence or topic: Artificial Intelligence is
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Generated Text:
#
# Artificial Intelligence is the most basic of all the human skills. AI is a highly complex tool that can be used extensively in the field of human intelligence research. Even though it is possible to work with, and even understand, AI, there are still some practical constraints.
#
# The key difference between AI and human intelligence research is that AI is not a scientific tool and human intelligence research is not. Instead, human intelligence researchers are trained to understand and study the data that they are studying and thus understand the data in different ways. In other words, human intelligence researchers must work with data as their primary purpose.
#
# Human Intelligence Research
#
# The first step in human intelligence research is the analysis of the data and to understand the data. This is the most basic step in the research of human intelligence. In this article, we will examine the techniques of human intelligence research in detail.
#
# The first step in human intelligence research is the analysis of the data and to understand the data. This is the most basic step in the research of human intelligence. In this article, we will examine the techniques of human intelligence research in detail. In this article, we will examine the techniques of human intelligence research in detail. A technique of human intelligence research is a method used to identify and identify information. Humans
