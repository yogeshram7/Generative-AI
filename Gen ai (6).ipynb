# %%
import sys
import torch
import transformers

print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("Transformers:", transformers.__version__)
# Out:
# Python: 3.10.20 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:13:20) [MSC v.1942 64 bit (AMD64)]
# PyTorch: 2.13.0+cpu
# Transformers: 4.55.4

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

print("BLIP libraries are working!")
# Out:
# BLIP libraries are working!

# %%
processor = BlipProcessor.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

print("Model loaded successfully!")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Model loaded successfully!

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\shaik\GENERATIVE - AI

# %%
Image.open("dog.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=547x365>

# %%
image = Image.open("dog.jpeg").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a puppy running through a field

# %%
Image.open("bird.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x360>

# %%
image = Image.open("bird.jpeg").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a red bird flying in the air

# %%
Image.open("car.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=638x480>

# %%
image = Image.open("car.jpeg").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a blue sports car on a white background
